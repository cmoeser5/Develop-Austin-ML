# %%
import pandas as pd
import random
import numpy as np
file_to_load = '../data/locations2.csv'

# %%
df = pd.read_csv(file_to_load)
df
# Out:
#        id                           name  rating  user_ratings_total  \
# 0     706                  Mikado Ryotei     4.5               369.0
# 1     707             To. Austin Archive     0.0                 0.0
# 2     708  Earl J. Pomerleau Pocket Park     4.3                 6.0
# 3     711             Jim Ernst Interest     0.0                 0.0
# 4     716                     La Placita     4.4               241.0
# ..    ...                            ...     ...                 ...
# 536   565                      Oak Acres     4.8                 5.0
# 537   260                  Burgerlicious     5.0                18.0
# 538   580                   P Men's Club     5.0                 5.0
# 539  5014                            NaN     NaN                 NaN
# 540  5047                            NaN     NaN                 NaN
#
#       latitude  longitude             types1              types2  \
# 0    30.373440 -97.724686                bar          restaurant
# ...

# %%
df= df[df['user_ratings_total'] != 0]

# %%
df
# Out:
#        id                            name  rating  user_ratings_total  \
# 0     706                   Mikado Ryotei     4.5               369.0
# 2     708   Earl J. Pomerleau Pocket Park     4.3                 6.0
# 4     716                      La Placita     4.4               241.0
# 5     717           Dittmar District Park     4.4               297.0
# 6     719  Rosa's Café & Tortilla Factory     4.2              1305.0
# ..    ...                             ...     ...                 ...
# 536   565                       Oak Acres     4.8                 5.0
# 537   260                   Burgerlicious     5.0                18.0
# 538   580                    P Men's Club     5.0                 5.0
# 539  5014                             NaN     NaN                 NaN
# 540  5047                             NaN     NaN                 NaN
#
#       latitude  longitude         types1               types2  \
# 0    30.373440 -97.724686            bar           restaurant
# ...

# %%
df= df[df['latitude'] != 0]
df
# Out:
#       id                             name  rating  user_ratings_total  \
# 0    706                    Mikado Ryotei     4.5               369.0
# 2    708    Earl J. Pomerleau Pocket Park     4.3                 6.0
# 4    716                       La Placita     4.4               241.0
# 5    717            Dittmar District Park     4.4               297.0
# 6    719   Rosa's Café & Tortilla Factory     4.2              1305.0
# ..   ...                              ...     ...                 ...
# 534  378  Heritage Oaks Neighborhood Park     4.7                43.0
# 535  287                     Centre North     3.6                16.0
# 536  565                        Oak Acres     4.8                 5.0
# 537  260                    Burgerlicious     5.0                18.0
# 538  580                     P Men's Club     5.0                 5.0
#
#       latitude  longitude         types1               types2  \
# 0    30.373440 -97.724686            bar           restaurant
# ...

# %%
df=df.drop(columns=["user_input"])

# %%
df
# Out:
#       id                             name  rating  user_ratings_total  \
# 0    706                    Mikado Ryotei     4.5               369.0
# 2    708    Earl J. Pomerleau Pocket Park     4.3                 6.0
# 4    716                       La Placita     4.4               241.0
# 5    717            Dittmar District Park     4.4               297.0
# 6    719   Rosa's Café & Tortilla Factory     4.2              1305.0
# ..   ...                              ...     ...                 ...
# 534  378  Heritage Oaks Neighborhood Park     4.7                43.0
# 535  287                     Centre North     3.6                16.0
# 536  565                        Oak Acres     4.8                 5.0
# 537  260                    Burgerlicious     5.0                18.0
# 538  580                     P Men's Club     5.0                 5.0
#
#       latitude  longitude         types1               types2  \
# 0    30.373440 -97.724686            bar           restaurant
# ...

# %%
df.to_csv('../data/location3.csv', index=False)

# %%
df['types'] = df[df.columns[6:13]].apply(
    lambda x: ','.join(x.dropna().astype(str)),
    axis=1
)
df
# Out:
#       id                             name  rating  user_ratings_total  \
# 0    706                    Mikado Ryotei     4.5               369.0
# 2    708    Earl J. Pomerleau Pocket Park     4.3                 6.0
# 4    716                       La Placita     4.4               241.0
# 5    717            Dittmar District Park     4.4               297.0
# 6    719   Rosa's Café & Tortilla Factory     4.2              1305.0
# ..   ...                              ...     ...                 ...
# 534  378  Heritage Oaks Neighborhood Park     4.7                43.0
# 535  287                     Centre North     3.6                16.0
# 536  565                        Oak Acres     4.8                 5.0
# 537  260                    Burgerlicious     5.0                18.0
# 538  580                     P Men's Club     5.0                 5.0
#
#       latitude  longitude         types1               types2  \
# 0    30.373440 -97.724686            bar           restaurant
# ...

# %%
df.to_csv('../data/location3.csv', index=False)
